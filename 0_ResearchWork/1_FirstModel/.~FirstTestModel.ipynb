# %% [markdown]
# # First model D+3

# %% [markdown]
# Here is a research notebook used for tests.

# %% [markdown]
# ### Import librairies:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
from sklearn.utils import shuffle
from sklearn.model_selection import KFold
import datetime

# %% [markdown]
# Install the jupyter-tensorboard extension if needed:
#
# https://github.com/lspvic/jupyter_tensorboard

# %%
#%pip install jupyter-tensorboard

# %% [markdown]
# Load Tensorboard:

# %%
# %load_ext tensorboard

# %% [markdown]
# ### Parameters:

# %%
#model
LOAD_MODEL = False 
MODEL_TO_LOAD_NAME = 'model.h5'
PATH_TO_MODELS = "Models/"

#dataset
CSV_PATH = "Datasets/"
CSV_NAME = "trainingDatasetDplus3.csv"
features_considered = ['temperature','humidite','IQ','IQ_J+1','IQ_J+2','IQ_J+3']

# %% [markdown]
# ### Import dataset:

# %%
df = pd.read_csv(CSV_PATH+CSV_NAME, header=0, delimiter=';')

features = df[features_considered]
features.index = df['Date']

#normalize
features['temperature'] = features['temperature'].apply(lambda x: (x - (-12.30))/((46.90)-(-12.30))) # to change
features['humidite'] = features['humidite'].apply(lambda x: x/100)
features['IQ'] = features['IQ'].apply(lambda x: x/10)

print(features.head())
features.plot(subplots=True)
plt.show()

dataset = features.values
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
#                   temperature  humidite   IQ  IQ_J+1  IQ_J+2  IQ_J+3
# Date
# 29/11/2019 12:00     0.351351      0.73  0.3       4       6       5
# 29/11/2019 09:00     0.314189      0.90  0.3       4       6       5
# 29/11/2019 06:00     0.320946      0.95  0.3       4       6       5
# 29/11/2019 03:00     0.334459      0.91  0.3       4       6       5
# 29/11/2019 00:00     0.347973      0.97  0.3       4       6       5

# %% [markdown]
# Check that the length of the dataset is a multiple of 8:

# %%
if len(dataset)%8!=0:
    raise Exception('ERROR ON THE LENGTH OF THE DATASET, EACH DAY MUST BE 8 MEASURES')

# %% [markdown]
# ### Create training data

# %%
RANDOM_SHUFFLE_SEED = 0

def createTraining(dataset,nb_measures,nb_features_x,nb_features_y):
    """
    shape the trainning dataset
    """
    chunks = [dataset[x*8:x*8+nb_measures] for x in range(0, int(len(dataset)/8))] #as there is 8 measures each day
    
    # we check that all the chuncks have the same length, as the nb_measures could be longuer than a day
    elementsToRemove = []
    for chunk in chunks: 
        if chunk.shape!=chunks[0].shape:
            elementsToRemove.append(chunk)    
    for e in elementsToRemove:
        chunks.remove(e)        
    chunks = np.array(chunks)  
    
    x_train = chunks[:,:,0:nb_features_x]
    y_train = chunks[:,0,nb_features_y:]
    x_train,y_train = shuffle(x_train,y_train, random_state=RANDOM_SHUFFLE_SEED)
    return(x_train, y_train)

# %%
nb_prev_measures_for_predict = 16

x_train,y_train = createTraining(dataset,nb_prev_measures_for_predict,len(features_considered)-3,3)

print("x_train ",x_train.shape)
print("y_train ",y_train.shape)
# Out:
# x_train  (695, 16, 3)
# y_train  (695, 3)
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ### Load the model or create it:

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense
# Out:
# Using TensorFlow backend.

# %%
OPTIMIZER = tf.train.RMSPropOptimizer(learning_rate=0.005)
LOSS = 'mae'

if LOAD_MODEL: 
    model = keras.models.load_model(PATH_TO_MODELS + MODEL_TO_LOAD_NAME)
    model.compile(OPTIMIZER, loss=LOSS)
else:
    # Model
    input_shape = (x_train.shape[-2],x_train.shape[-1])

    model = Sequential()
    model.add(LSTM(512,input_shape=input_shape,name='LSTM_layer'))
    model.add(Dense(3,name="Dense_layer"))
    model.compile(optimizer=OPTIMIZER, loss=LOSS)
    model.summary()
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# LSTM_layer (LSTM)            (None, 512)               1056768
# _________________________________________________________________
# Dense_layer (Dense)          (None, 3)                 1539
# =================================================================
# Total params: 1,058,307
# Trainable params: 1,058,307
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train

# %%
EPOCHS = 40
kfoldsize = 5

tensor_board = tf.keras.callbacks.TensorBoard('.\logs\\'+str(datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")))

for train_index,test_index in KFold(kfoldsize).split(x_train):
    x,x_val = x_train[train_index],x_train[test_index]
    y,y_val = y_train[train_index],y_train[test_index]
    
    model.fit(x=x, y=y, validation_data=(x_val,y_val),epochs=EPOCHS,callbacks = [tensor_board])
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\rmsprop.py:119: calling Ones.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 556 samples, validate on 139 samples
# Epoch 1/40
# 556/556 [==============================] - 3s 5ms/step - loss: 4.0072 - val_loss: 3.7794
# Epoch 2/40
# 556/556 [==============================] - 2s 3ms/step - loss: 3.5733 - val_loss: 2.7758
# Epoch 3/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.4426 - val_loss: 1.2030
# Epoch 4/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.1502 - val_loss: 1.0281
# Epoch 5/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.2953 - val_loss: 1.1938
# Epoch 6/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.1630 - val_loss: 1.1315
# Epoch 7/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.1560 - val_loss: 1.0616
# Epoch 8/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.1508 - val_loss: 1.0966
# Epoch 9/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.2270 - val_loss: 1.0427
# Epoch 10/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0951 - val_loss: 1.0523
# Epoch 11/40
# 556/556 [==============================] - 1s 3ms/step - loss: 1.0910 - val_loss: 1.0563
# Epoch 12/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0857 - val_loss: 1.0405
# Epoch 13/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0912 - val_loss: 1.0934
# Epoch 14/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.1108 - val_loss: 1.0553
# Epoch 15/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0871 - val_loss: 1.0670
# Epoch 16/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0854 - val_loss: 1.0367
# Epoch 17/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0721 - val_loss: 1.0427
# Epoch 18/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0820 - val_loss: 1.0313
# Epoch 19/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0852 - val_loss: 1.0460
# Epoch 20/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0733 - val_loss: 1.0379
# Epoch 21/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0873 - val_loss: 1.0839
# Epoch 22/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0614 - val_loss: 1.0781
# Epoch 23/40
# 556/556 [==============================] - 4s 7ms/step - loss: 1.0650 - val_loss: 1.0827
# Epoch 24/40
# 556/556 [==============================] - 3s 5ms/step - loss: 1.0723 - val_loss: 1.0317
# Epoch 25/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0649 - val_loss: 1.0576
# Epoch 26/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0747 - val_loss: 1.0521
# Epoch 27/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.2515 - val_loss: 1.0331
# Epoch 28/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.2482 - val_loss: 1.0576
# Epoch 29/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0592 - val_loss: 1.0334
# Epoch 30/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0526 - val_loss: 1.1570
# Epoch 31/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0700 - val_loss: 1.0553
# Epoch 32/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0616 - val_loss: 1.0117
# Epoch 33/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0709 - val_loss: 1.1181
# Epoch 34/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0588 - val_loss: 1.2248
# Epoch 35/40
# 556/556 [==============================] - 2s 4ms/step - loss: 1.0752 - val_loss: 1.0095
# Epoch 36/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0177 - val_loss: 0.9858
# Epoch 37/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9974 - val_loss: 0.9610
# Epoch 38/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.0085 - val_loss: 0.9936
# Epoch 39/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9698 - val_loss: 1.0113
# Epoch 40/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9750 - val_loss: 0.9251
# Train on 556 samples, validate on 139 samples
# Epoch 1/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9578 - val_loss: 0.9487
# Epoch 2/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9660 - val_loss: 1.1090
# Epoch 3/40
# 556/556 [==============================] - 2s 3ms/step - loss: 1.2347 - val_loss: 0.9936
# Epoch 4/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9573 - val_loss: 0.9328
# Epoch 5/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9266 - val_loss: 1.0384
# Epoch 6/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9329 - val_loss: 0.9282
# Epoch 7/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9286 - val_loss: 0.9301
# Epoch 8/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9423 - val_loss: 0.9761
# Epoch 9/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9218 - val_loss: 0.9400
# Epoch 10/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9215 - val_loss: 1.0448
# Epoch 11/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9211 - val_loss: 0.9479
# Epoch 12/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9081 - val_loss: 0.9858
# Epoch 13/40
# 556/556 [==============================] - 5s 8ms/step - loss: 0.9216 - val_loss: 1.1063
# Epoch 14/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9136 - val_loss: 1.0543
# Epoch 15/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9070 - val_loss: 1.0023
# Epoch 16/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8972 - val_loss: 0.9348
# Epoch 17/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8987 - val_loss: 1.0006
# Epoch 18/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8946 - val_loss: 0.9444
# Epoch 19/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8951 - val_loss: 1.0999
# Epoch 20/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9160 - val_loss: 0.9731
# Epoch 21/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8964 - val_loss: 1.0100
# Epoch 22/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9120 - val_loss: 0.9182
# Epoch 23/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9110 - val_loss: 0.9376
# Epoch 24/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8936 - val_loss: 1.0189
# Epoch 25/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8857 - val_loss: 0.9562
# Epoch 26/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8944 - val_loss: 0.9457
# Epoch 27/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8981 - val_loss: 1.0484
# Epoch 28/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9018 - val_loss: 1.0078
# Epoch 29/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8940 - val_loss: 0.9167
# Epoch 30/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8889 - val_loss: 0.9377
# Epoch 31/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8746 - val_loss: 0.9508
# Epoch 32/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8954 - val_loss: 0.9828
# Epoch 33/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8752 - val_loss: 0.9509
# Epoch 34/40
# 556/556 [==============================] - 3s 5ms/step - loss: 0.8699 - val_loss: 0.9484
# Epoch 35/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8865 - val_loss: 0.9214
# Epoch 36/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8784 - val_loss: 0.9551
# Epoch 37/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8950 - val_loss: 0.9186
# Epoch 38/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8908 - val_loss: 0.9317
# Epoch 39/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8831 - val_loss: 0.9390
# Epoch 40/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8874 - val_loss: 0.9203
# Train on 556 samples, validate on 139 samples
# Epoch 1/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8967 - val_loss: 0.8335
# Epoch 2/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9166 - val_loss: 0.9627
# Epoch 3/40
# 556/556 [==============================] - 5s 9ms/step - loss: 0.9050 - val_loss: 0.8402
# Epoch 4/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9168 - val_loss: 0.8278
# Epoch 5/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8943 - val_loss: 0.8932
# Epoch 6/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8906 - val_loss: 0.8335
# Epoch 7/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8858 - val_loss: 0.8883
# Epoch 8/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9056 - val_loss: 0.9357
# Epoch 9/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9130 - val_loss: 0.8645
# Epoch 10/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9022 - val_loss: 0.8880
# Epoch 11/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8975 - val_loss: 0.8342
# Epoch 12/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9013 - val_loss: 0.8377
# Epoch 13/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8930 - val_loss: 0.8502
# Epoch 14/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8995 - val_loss: 0.8160
# Epoch 15/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8945 - val_loss: 0.8115
# Epoch 16/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9285 - val_loss: 0.8992
# Epoch 17/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8932 - val_loss: 0.8539
# Epoch 18/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8965 - val_loss: 0.8076
# Epoch 19/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8873 - val_loss: 0.8346
# Epoch 20/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9042 - val_loss: 0.8668
# Epoch 21/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9077 - val_loss: 0.8441
# Epoch 22/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8809 - val_loss: 0.8414
# Epoch 23/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8864 - val_loss: 0.9191
# Epoch 24/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8930 - val_loss: 0.8565
# Epoch 25/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8969 - val_loss: 0.8859
# Epoch 26/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8914 - val_loss: 0.9560
# Epoch 27/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8837 - val_loss: 0.8708
# Epoch 28/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8869 - val_loss: 0.8266
# Epoch 29/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.9269 - val_loss: 0.9222
# Epoch 30/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9038 - val_loss: 0.9396
# Epoch 31/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8850 - val_loss: 0.8642
# Epoch 32/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8796 - val_loss: 1.1506
# Epoch 33/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.9101 - val_loss: 0.8886
# Epoch 34/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8885 - val_loss: 0.8513
# Epoch 35/40
# 556/556 [==============================] - 4s 7ms/step - loss: 0.8711 - val_loss: 0.8301
# Epoch 36/40
# 556/556 [==============================] - 4s 6ms/step - loss: 0.8793 - val_loss: 0.8700
# Epoch 37/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8750 - val_loss: 0.8343
# Epoch 38/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8852 - val_loss: 0.8543
# Epoch 39/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8733 - val_loss: 0.9095
# Epoch 40/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8810 - val_loss: 0.8247
# Train on 556 samples, validate on 139 samples
# Epoch 1/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8480 - val_loss: 0.9561
# Epoch 2/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8353 - val_loss: 0.9497
# Epoch 3/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8414 - val_loss: 1.0798
# Epoch 4/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8910 - val_loss: 0.9419
# Epoch 5/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8312 - val_loss: 1.0127
# Epoch 6/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8460 - val_loss: 0.9606
# Epoch 7/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8409 - val_loss: 0.9673
# Epoch 8/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8380 - val_loss: 0.9512
# Epoch 9/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8437 - val_loss: 0.9751
# Epoch 10/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8329 - val_loss: 0.9425
# Epoch 11/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8509 - val_loss: 0.9519
# Epoch 12/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8416 - val_loss: 0.9818
# Epoch 13/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8375 - val_loss: 0.9614
# Epoch 14/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8421 - val_loss: 0.9665
# Epoch 15/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8475 - val_loss: 0.9634
# Epoch 16/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8429 - val_loss: 0.9411
# Epoch 17/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8368 - val_loss: 0.9647
# Epoch 18/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8582 - val_loss: 0.9388
# Epoch 19/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8282 - val_loss: 0.9660
# Epoch 20/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8322 - val_loss: 0.9638
# Epoch 21/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8431 - val_loss: 0.9776
# Epoch 22/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8349 - val_loss: 0.9723
# Epoch 23/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8385 - val_loss: 0.9586
# Epoch 24/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8368 - val_loss: 0.9934
# Epoch 25/40
# 556/556 [==============================] - 3s 5ms/step - loss: 0.8304 - val_loss: 0.9582
# Epoch 26/40
# 556/556 [==============================] - 5s 8ms/step - loss: 0.8327 - val_loss: 0.9650
# Epoch 27/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8432 - val_loss: 0.9612
# Epoch 28/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8316 - val_loss: 0.9701
# Epoch 29/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8301 - val_loss: 0.9749
# Epoch 30/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8353 - val_loss: 1.0030
# Epoch 31/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8352 - val_loss: 0.9432
# Epoch 32/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8307 - val_loss: 0.9618
# Epoch 33/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8324 - val_loss: 0.9801
# Epoch 34/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8245 - val_loss: 0.9790
# Epoch 35/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8348 - val_loss: 0.9673
# Epoch 36/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8211 - val_loss: 0.9457
# Epoch 37/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8507 - val_loss: 0.9995
# Epoch 38/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8214 - val_loss: 0.9515
# Epoch 39/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8163 - val_loss: 0.9721
# Epoch 40/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8331 - val_loss: 0.9851
# Train on 556 samples, validate on 139 samples
# Epoch 1/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8556 - val_loss: 0.8143
# Epoch 2/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8749 - val_loss: 0.8408
# Epoch 3/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8690 - val_loss: 0.7981
# Epoch 4/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8611 - val_loss: 0.7999
# Epoch 5/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8833 - val_loss: 0.8205
# Epoch 6/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8680 - val_loss: 0.8444
# Epoch 7/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8645 - val_loss: 0.7739
# Epoch 8/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8743 - val_loss: 0.8074
# Epoch 9/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8802 - val_loss: 0.8101
# Epoch 10/40
# 556/556 [==============================] - 3s 5ms/step - loss: 0.8663 - val_loss: 0.8180
# Epoch 11/40
# 556/556 [==============================] - 3s 6ms/step - loss: 0.8722 - val_loss: 0.7857
# Epoch 12/40
# 556/556 [==============================] - 3s 5ms/step - loss: 0.8544 - val_loss: 0.8106
# Epoch 13/40
# 556/556 [==============================] - 6s 11ms/step - loss: 0.8539 - val_loss: 0.8205
# Epoch 14/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8663 - val_loss: 0.8128
# Epoch 15/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8593 - val_loss: 0.7766
# Epoch 16/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8585 - val_loss: 0.8296
# Epoch 17/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8608 - val_loss: 0.7954
# Epoch 18/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8599 - val_loss: 0.8183
# Epoch 19/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8943 - val_loss: 0.8215
# Epoch 20/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8563 - val_loss: 0.8465
# Epoch 21/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8532 - val_loss: 0.8113
# Epoch 22/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8541 - val_loss: 0.8461
# Epoch 23/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8794 - val_loss: 0.8187
# Epoch 24/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8740 - val_loss: 0.8156
# Epoch 25/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8724 - val_loss: 0.8355
# Epoch 26/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8675 - val_loss: 0.8122
# Epoch 27/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8518 - val_loss: 0.8198
# Epoch 28/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8605 - val_loss: 0.8239
# Epoch 29/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8585 - val_loss: 0.7815
# Epoch 30/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8589 - val_loss: 0.7932
# Epoch 31/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8618 - val_loss: 0.8271
# Epoch 32/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8498 - val_loss: 0.9213
# Epoch 33/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8599 - val_loss: 0.8301
# Epoch 34/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8479 - val_loss: 0.8168
# Epoch 35/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8491 - val_loss: 0.8207
# Epoch 36/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8504 - val_loss: 0.7979
# Epoch 37/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8541 - val_loss: 0.7800
# Epoch 38/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8478 - val_loss: 0.8027
# Epoch 39/40
# 556/556 [==============================] - 2s 3ms/step - loss: 0.8633 - val_loss: 0.8322
# Epoch 40/40
# 556/556 [==============================] - 2s 4ms/step - loss: 0.8439 - val_loss: 0.8328

# %% [markdown]
# ### See the training in tensorboard

# %%
#%tensorboard --logdir=./logs

# %% [markdown]
# ### See the results

# %%
def calc_accuracy_3days(y_pred,y_true):
    """
    calculate the accurracy of the prediction according to the true value for each day [D+1, D+2, D+3]
    """
    accuracy = [0,0,0]
    for pred,true in zip (y_pred,y_true):
        for plusDay in range(3):
            if true[plusDay] == round(pred[plusDay]):
                accuracy[plusDay]+=1
    return(np.array(accuracy)/len(y_true)*100)
    
def mean_error_3days(y_pred,y_true):
    """
    calculate the mean error between the prediction and the true value for each day [D+1, D+2, D+3]
    """
    error = [0,0,0]
    for pred,true in zip (y_pred,y_true):
        for plusDay in range(3):
            error[plusDay] += abs(true[plusDay] - pred[plusDay])
    return(np.array(error)/len(y_true))

# %% [markdown]
# Calculate the accuracy and mean error for each day [D+1, D+2, D+3]:

# %%
y_pred = model.predict(x_train)
accuracy = calc_accuracy_3days(y_pred,y_train)
meanError = mean_error_3days(y_pred,y_train)

# %% [markdown]
# Show the results in graphs:

# %%
print('Prediction of the air index quality (on training data)')
for plusDay in range(3):
    #plot predict    
    plt.plot(y_train[:,plusDay], label='Real')
    plt.plot(y_pred[:,plusDay], label='Prediction')
    plt.xlabel('Days', fontsize=18)
    plt.ylabel('D+'+str(plusDay+1), fontsize=16)
    plt.legend()
    plt.show()

    print("Accuracy with training data:",round(accuracy[plusDay],2),"%")
    print("Mean error with training data:",round(meanError[plusDay],2))
# Out:
# Prediction of the air index quality (on training data)
# Accuracy with training data: 50.5 %
# Mean error with training data: 0.7
# Accuracy with training data: 43.17 %
# Mean error with training data: 0.85
# Accuracy with training data: 36.26 %
# Mean error with training data: 0.98
