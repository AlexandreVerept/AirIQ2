# %% [markdown]
# # Cleaning the synop dataset
#
# It can be found here:
# https://donneespubliques.meteofrance.fr/?fond=produit&id_produit=90&id_rubrique=32
#
# ### Import data:

# %%
import pandas as pd
import os
import glob

print(os.getcwd())
# Out:
# C:\Users\avere\Documents\Cours\Projet PPAL\AirIQ2\0_ResearchWork\3_CreateAndCleanDatasets

# %%
filesList = glob.glob(os.path.join("HistoricDataset/synopDownload",'*.csv.gz'))
    
dfList = []
    
for filename in filesList:        
    df = pd.read_csv(filename, header=0, delimiter=';')

    #select data from Lille-Lesquin
    df = df.loc[df['numer_sta'] == 7015]
    #change datetime format
    df['date'] = pd.to_datetime(df['date'],format = '%Y%m%d%H%M%S')
    dfList.append(df)

# concatenate
df = pd.concat(dfList, axis=0, ignore_index=True)    
df.head()
# Out:
#    numer_sta                date    pmer tend cod_tend   dd        ff  \
# 0       7015 1996-01-01 00:00:00  100020  100        1    0  0.000000
# 1       7015 1996-01-01 03:00:00  100080   60        0  150  2.000000
# 2       7015 1996-01-01 06:00:00  100080    0        5  150  2.000000
# 3       7015 1996-01-01 09:00:00  100110   30        0   90  2.000000
# 4       7015 1996-01-01 12:00:00  100110    0        0   70  1.000000
#
#             t          td   u  ... nnuage2 ctype2 hnuage2 nnuage3 ctype3  \
# 0  275.950000  275.350000  96  ...      mq     mq      mq      mq     mq
# 1  275.250000  274.850000  97  ...      mq     mq      mq      mq     mq
# 2  275.150000  274.750000  97  ...      mq     mq      mq      mq     mq
# 3  275.350000  274.950000  97  ...      mq     mq      mq      mq     mq
# 4  276.450000  276.040000  97  ...      mq     mq      mq      mq     mq
#
#   hnuage3 nnuage4 ctype4 hnuage4 Unnamed: 59
# 0      mq      mq     mq      mq         NaN
# 1      mq      mq     mq      mq         NaN
# 2      mq      mq     mq      mq         NaN
# 3      mq      mq     mq      mq         NaN
# 4      mq      mq     mq      mq         NaN
#
# [5 rows x 60 columns]

# %% [markdown]
# Here is the description of the dataset:
# ![id station](pictures/doc_parametres_synop_168-1.jpg)
# And the id station of Lille
# ![dataset description](pictures/idstation.png)

# %% [markdown]
# ### Selecting features:

# %%
interestingFeatures = ["date","pres","dd","ff","u","t"]
df = df[interestingFeatures]
df.head()
# Out:
#                  date   pres   dd        ff   u           t
# 0 1996-01-01 00:00:00  99380    0  0.000000  96  275.950000
# 1 1996-01-01 03:00:00  99440  150  2.000000  97  275.250000
# 2 1996-01-01 06:00:00  99440  150  2.000000  97  275.150000
# 3 1996-01-01 09:00:00  99470   90  2.000000  97  275.350000
# 4 1996-01-01 12:00:00  99470   70  1.000000  97  276.450000

# %%
df.columns = ["date", "pressure","wind_direction","wind_force","humidity","temperature"]
df = df.sort_values(by=['date'])
df.index=df['date']
df.head()
# Out:
#                                    date pressure wind_direction wind_force  \
# date
# 1996-01-01 00:00:00 1996-01-01 00:00:00    99380              0   0.000000
# 1996-01-01 03:00:00 1996-01-01 03:00:00    99440            150   2.000000
# 1996-01-01 06:00:00 1996-01-01 06:00:00    99440            150   2.000000
# 1996-01-01 09:00:00 1996-01-01 09:00:00    99470             90   2.000000
# 1996-01-01 12:00:00 1996-01-01 12:00:00    99470             70   1.000000
#
#                     humidity temperature
# date
# 1996-01-01 00:00:00       96  275.950000
# 1996-01-01 03:00:00       97  275.250000
# 1996-01-01 06:00:00       97  275.150000
# 1996-01-01 09:00:00       97  275.350000
# 1996-01-01 12:00:00       97  276.450000

# %% [markdown]
# ### Cleaning missing values

# %%
import numpy as np
df = df.replace('mq',np.NaN)

# %%
df.isna().sum()
# Out:
# date                0
# pressure           17
# wind_direction    137
# wind_force        134
# humidity           25
# temperature        11
# dtype: int64

# %%
df = df.fillna(method='ffill')
df.isna().sum()
# Out:
# date              0
# pressure          0
# wind_direction    0
# wind_force        0
# humidity          0
# temperature       0
# dtype: int64

# %% [markdown]
# ### Cleaning the types of data:

# %%
df.dtypes
# Out:
# date              datetime64[ns]
# pressure                  object
# wind_direction            object
# wind_force                object
# humidity                  object
# temperature               object
# dtype: object

# %%
df["pressure"] = df["pressure"].astype(int)
df["wind_direction"] = df["wind_direction"].astype(int)
df["wind_force"] = df["wind_force"].astype(float)
df["humidity"] = df["humidity"].astype(int)
df["temperature"] = df["temperature"].astype(float)
df.dtypes
# Out:
# date              datetime64[ns]
# pressure                   int32
# wind_direction             int32
# wind_force               float64
# humidity                   int32
# temperature              float64
# dtype: object

# %%
df.head()
# Out:
#                                    date  pressure  wind_direction  wind_force  \
# date
# 1996-01-01 00:00:00 1996-01-01 00:00:00     99380               0         0.0
# 1996-01-01 03:00:00 1996-01-01 03:00:00     99440             150         2.0
# 1996-01-01 06:00:00 1996-01-01 06:00:00     99440             150         2.0
# 1996-01-01 09:00:00 1996-01-01 09:00:00     99470              90         2.0
# 1996-01-01 12:00:00 1996-01-01 12:00:00     99470              70         1.0
#
#                      humidity  temperature
# date
# 1996-01-01 00:00:00        96       275.95
# 1996-01-01 03:00:00        97       275.25
# 1996-01-01 06:00:00        97       275.15
# 1996-01-01 09:00:00        97       275.35
# 1996-01-01 12:00:00        97       276.45

# %%
df.describe()
# Out:
#             pressure  wind_direction    wind_force      humidity   temperature
# count   70381.000000    70381.000000  70381.000000  70381.000000  70381.000000
# mean   101026.891349      186.342905      4.267139     79.244611    284.229234
# std       967.774294       97.296695      2.501746     15.969099      6.836402
# min     96100.000000        0.000000      0.000000     18.000000    260.850000
# 25%    100460.000000      110.000000      2.400000     70.000000    279.350000
# 50%    101090.000000      200.000000      4.100000     84.000000    284.150000
# 75%    101670.000000      260.000000      5.900000     92.000000    288.950000
# max    104280.000000      360.000000     22.100000    100.000000    320.050000

# %%
df.resample('3H').mean()
# Out:
#                      pressure  wind_direction  wind_force  humidity  \
# date
# 1996-01-01 00:00:00   99380.0             0.0         0.0      96.0
# 1996-01-01 03:00:00   99440.0           150.0         2.0      97.0
# 1996-01-01 06:00:00   99440.0           150.0         2.0      97.0
# 1996-01-01 09:00:00   99470.0            90.0         2.0      97.0
# 1996-01-01 12:00:00   99470.0            70.0         1.0      97.0
# ...                       ...             ...         ...       ...
# 2020-02-29 09:00:00   98190.0           180.0        10.4      74.0
# 2020-02-29 12:00:00   98270.0           250.0        11.7      83.0
# 2020-02-29 15:00:00   98600.0           240.0        10.8      57.0
# 2020-02-29 18:00:00   98820.0           230.0         7.5      59.0
# 2020-02-29 21:00:00   98890.0           210.0         8.6      80.0
#
#                      temperature
# date
# 1996-01-01 00:00:00       275.95
# 1996-01-01 03:00:00       275.25
# 1996-01-01 06:00:00       275.15
# 1996-01-01 09:00:00       275.35
# 1996-01-01 12:00:00       276.45
# ...                          ...
# 2020-02-29 09:00:00       283.45
# 2020-02-29 12:00:00       280.55
# 2020-02-29 15:00:00       282.35
# 2020-02-29 18:00:00       280.85
# 2020-02-29 21:00:00       277.85
#
# [70608 rows x 5 columns]

# %% [markdown]
# ### Save dataset

# %%
df.to_csv("HistoricDataset/synopComplete/completeSynopDataset.csv", index=False,sep=';')
